# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshchotwani/SD_Harsh_0111/blob/main/list4_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [1,2,3,4]

# %%
nums[0]
# Out:
# 1

# %%
nums[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1008/2255194133.py in <cell line: 0>()
# ----> 1 nums[4]
#
# IndexError: list index out of range

# %%
type(nums)
# Out:
# list

# %%
lst=[2,3,4.0,"Harsh"]
