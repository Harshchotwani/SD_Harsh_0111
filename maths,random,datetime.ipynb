# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshchotwani/SD_Harsh_0111/blob/main/maths%2Crandom%2Cdatetime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
num=25
print(math.sqrt(num))
# Out:
# 5.0

# %%
print(math.pow(2,5
              ))
# Out:
# 32.0

# %%
print(math.factorial(5
                     ))
# Out:
# 120

# %%
print(math.ceil(4.2))

# %%
print(abs(-50))
# Out:
# 50

# %%
print(math.gcd(24,36))
# Out:
# 12

# %%
print(math.lcm(12,18))
# Out:
# 36

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.sin(math.radians(90)))
# Out:
# 1.0

# %%
print(math.e
      )
# Out:
# 2.718281828459045

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2026-07-20 06:31:29.933745

# %%
print(datetime.datetime.now().year)
# Out:
# 2026

# %%
print(datetime.datetime.now().month)
# Out:
# 7

# %%
import time
from IPython.display import clear_output
from datetime import datetime
import pytz

while True:
  clear_output(wait=True)
  # Get current UTC time
  utc_now = datetime.now(pytz.utc)
  # Define Indian Standard Time (IST) timezone
  ist_timezone = pytz.timezone('Asia/Kolkata')
  # Convert UTC time to IST
  ist_now = utc_now.astimezone(ist_timezone)
  current_time = ist_now.strftime("%I:%M:%S %p")
  print("DIGITAL CLOCK (INDIAN ZONE)")
  print(current_time)
  time.sleep(1)
# Out:
# 20

# %%
q1frtfy0 ,p74p/rint(datetime.datetime.now().hour)

# %%
import datetime
now = datetime.datetime.now()
print(today.strftime("%A"))

# %%
import datetime
import time
while True:
  print(datetime.datetime.now().strftime("%H:%M:%S"))
time.sleep(1)
# Out:
# Streaming output truncated to the last 5000 lines.
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# 08:56:41
# ...

# %%
import time
from IPython.display import clear_output
from datetime import datetime
while True:
  clear_output(wait=True)
  current_time=Datetime.mow().strftime("%I:%M:%S:%P")
  print("DIGITAL CLOCK")
  print(current_time)
  time.sleep(1)

# %%
import time
from IPython.display import clear_output
from datetime import datetime
from zoneinfo import zoneInfo
while True:
  clear_output(wait=True)
  ist_time = datetime.now(ZoneInfo("Asia/Kolkata"))
  print("DIGITAL CLOCK")
  print("Date:",ist_time.strftime("%d-%m-%y"))
  print("Day:",ist_time.strftime("%A"))
  print("Time:",ist_time.strftime("%I:%M:%S %p"))
  print("TimeZone:",ist_time.tzname())
  time.sleep(1)
